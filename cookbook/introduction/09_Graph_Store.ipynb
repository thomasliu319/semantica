# %% [markdown]
# # Graph Store Module
#
# ## Overview
#
# The Graph Store module provides a unified interface for working with property graph databases. It supports multiple backends (Neo4j, FalkorDB) and offers comprehensive features for storing, querying, and analyzing graph data.
#
# ### Key Features
#
# - **Multi-Backend Support**: Neo4j (Enterprise), FalkorDB (Redis-based)
# - **Full CRUD Operations**: Create, read, update, delete nodes and relationships
# - **Cypher Query Language**: Execute complex graph queries with OpenCypher support
# - **Graph Analytics**: Built-in algorithms for centrality, community detection, path finding
# - **Batch Operations**: Optimized bulk data loading with progress tracking
# - **Transaction Support**: ACID transactions with rollback capabilities
# - **Index Management**: Create and manage indexes for performance optimization
# - **Convenience Functions**: Simple function-based API for common operations
#
# ### Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# 1. Initialize and configure GraphStore with different backends
# 2. Perform CRUD operations on nodes and relationships
# 3. Execute Cypher queries for complex graph operations
# 4. Use graph analytics algorithms (shortest path, neighbors, centrality)
# 5. Update and delete graph data
# 6. Use batch operations for efficient data loading
# 7. Work with convenience functions and configuration management
# 8. Choose the right backend for your use case
#
# ---
#
# ## Installation
#
# ### Core Installation
#
# ```bash
# # Install Semantica
# pip install semantica
#
# # Or install with all optional dependencies
# pip install semantica[all]
# ```
#
# ### Backend-Specific Dependencies
#
# ```bash
# # For Neo4j (requires Neo4j server)
# pip install neo4j
#
# # For FalkorDB (requires Redis/FalkorDB server)
# pip install falkordb
# ```
#
# ### Docker Setup (Optional)
#
# For FalkorDB, you can run it in Docker:
#
# ```bash
# docker run -p 6379:6379 -p 3000:3000 -it --rm \
#   -v ./data:/var/lib/falkordb/data \
#   falkordb/falkordb
# ```
#
# ---
#
# ## Backend Comparison
#
# | Backend | Best For | Deployment | Features |
# |---------|----------|------------|----------|
# | **Neo4j** | Enterprise applications, production systems | Server/Cloud | Full Cypher, APOC procedures, multi-database |
# | **FalkorDB** | LLM applications, real-time systems, high performance | Redis-based | Ultra-fast, sparse matrix operations |
#
# **Recommendation**: Use **Neo4j** for enterprise production systems or **FalkorDB** for high-performance real-time applications.

# %%
# !pip install semantica
# Out:
# Requirement already satisfied: semantica in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (0.6.8)
# Requirement already satisfied: numpy>=2.0.2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (2.5.3)
# Requirement already satisfied: pandas>=1.3.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (3.0.5)
# Requirement already satisfied: scipy>=1.13.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (1.18.1)
# Requirement already satisfied: scikit-learn>=1.7.2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (1.9.1)
# Requirement already satisfied: umap-learn>=0.5.12 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (0.5.12)
# Requirement already satisfied: spacy>=3.4.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (3.8.16)
# Requirement already satisfied: transformers>=4.20.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (5.17.0)
# Requirement already satisfied: torch>=1.13.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (2.14.0)
# Requirement already satisfied: sentence-transformers>=2.2.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (6.0.1)
# Requirement already satisfied: rdflib>=6.2.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (7.6.0)
# Requirement already satisfied: networkx>=2.8.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (3.6.1)
# Requirement already satisfied: matplotlib>=3.9.4 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (3.11.2)
# Requirement already satisfied: seaborn>=0.13.2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (0.13.2)
# Requirement already satisfied: plotly>=6.8.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (7.0.0)
# Requirement already satisfied: ipywidgets>=8.0.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (8.1.9)
# Requirement already satisfied: requests>=2.34.2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (2.34.2)
# Requirement already satisfied: GitPython>=3.1.58 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (3.1.62)
# Requirement already satisfied: chardet>=7.4.3 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (7.6.0)
# Requirement already satisfied: protobuf<8.0,>=5.29.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (7.36.1)
# Requirement already satisfied: grpcio>=1.81.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (1.83.1)
# Requirement already satisfied: beautifulsoup4>=4.15.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (4.15.0)
# Requirement already satisfied: lxml>=6.1.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (6.1.3)
# Requirement already satisfied: python-docx>=1.2.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (1.2.0)
# Requirement already satisfied: openpyxl>=3.1.5 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (3.1.5)
# Requirement already satisfied: pillow>=12.2.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (12.3.0)
# Requirement already satisfied: librosa>=0.9.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (1.0.0)
# Requirement already satisfied: opencv-python>=4.13.0.92 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (5.0.0.93)
# Requirement already satisfied: faiss-cpu>=1.7.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (1.15.0)
# Requirement already satisfied: fastembed>=0.2.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (0.8.0)
# Requirement already satisfied: onnxruntime>=1.20.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (1.30.0)
# Requirement already satisfied: tokenizers>=0.15.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (0.23.2)
# Requirement already satisfied: pydantic>=2.13.4 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (2.13.5)
# Requirement already satisfied: click>=8.4.2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (8.5.0)
# Requirement already satisfied: rich>=12.5.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (15.0.0)
# Requirement already satisfied: tqdm>=4.68.3 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (4.70.1)
# Requirement already satisfied: pyyaml>=6.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (6.0.3)
# Requirement already satisfied: toml>=0.10.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (0.10.2)
# Requirement already satisfied: python-dotenv>=1.2.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (1.2.3)
# Requirement already satisfied: loguru>=0.7.3 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (0.7.3)
# Requirement already satisfied: structlog>=22.1.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (26.1.0)
# Requirement already satisfied: gensim>=4.4.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (4.4.0)
# Requirement already satisfied: httpx<0.29.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (0.28.1)
# Requirement already satisfied: pyarrow>=14.0.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from semantica) (25.0.1)
# Requirement already satisfied: anyio in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from httpx<0.29.0->semantica) (4.15.1)
# Requirement already satisfied: certifi in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from httpx<0.29.0->semantica) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from httpx<0.29.0->semantica) (1.0.9)
# Requirement already satisfied: idna in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from httpx<0.29.0->semantica) (3.19)
# Requirement already satisfied: h11>=0.16 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from httpcore==1.*->httpx<0.29.0->semantica) (0.16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from beautifulsoup4>=4.15.0->semantica) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from beautifulsoup4>=4.15.0->semantica) (4.16.0)
# Requirement already satisfied: packaging in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from faiss-cpu>=1.7.0->semantica) (26.3)
# Requirement already satisfied: huggingface-hub<2.0,>=0.20 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from fastembed>=0.2.0->semantica) (1.31.0)
# Requirement already satisfied: mmh3<6.0.0,>=4.1.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from fastembed>=0.2.0->semantica) (5.3.0)
# Requirement already satisfied: py-rust-stemmers<0.2.0,>=0.1.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from fastembed>=0.2.0->semantica) (0.1.8)
# Requirement already satisfied: filelock>=3.10.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.20->fastembed>=0.2.0->semantica) (3.32.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.20->fastembed>=0.2.0->semantica) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.20->fastembed>=0.2.0->semantica) (1.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from requests>=2.34.2->semantica) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from requests>=2.34.2->semantica) (2.7.0)
# Requirement already satisfied: smart_open>=1.8.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from gensim>=4.4.0->semantica) (8.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from GitPython>=3.1.58->semantica) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.58->semantica) (5.0.3)
# Requirement already satisfied: comm>=0.1.3 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from ipywidgets>=8.0.0->semantica) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from ipywidgets>=8.0.0->semantica) (9.17.1)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from ipywidgets>=8.0.0->semantica) (5.16.1)
# Requirement already satisfied: widgetsnbextension~=4.0.16 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from ipywidgets>=8.0.0->semantica) (4.0.16)
# Requirement already satisfied: jupyterlab_widgets~=3.0.17 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from ipywidgets>=8.0.0->semantica) (3.0.17)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->semantica) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->semantica) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->semantica) (0.2.2)
# Requirement already satisfied: pexpect>4.6 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->semantica) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->semantica) (3.0.53)
# Requirement already satisfied: psutil>=7 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->semantica) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->semantica) (2.21.0)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->semantica) (0.6.3)
# Requirement already satisfied: wcwidth>=0.1.4 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.0.0->semantica) (0.8.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets>=8.0.0->semantica) (0.8.7)
# Requirement already satisfied: numba>=0.61.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from librosa>=0.9.0->semantica) (0.67.0)
# Requirement already satisfied: joblib>=1.2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from librosa>=0.9.0->semantica) (1.6.0)
# Requirement already satisfied: decorator>=5.2.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from librosa>=0.9.0->semantica) (5.3.1)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from librosa>=0.9.0->semantica) (0.14.0)
# Requirement already satisfied: pooch>=1.7 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from librosa>=0.9.0->semantica) (1.9.0)
# Requirement already satisfied: soxr>=1.0.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from librosa>=0.9.0->semantica) (1.1.0)
# Requirement already satisfied: lazy_loader>=0.3 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from librosa>=0.9.0->semantica) (0.5)
# Requirement already satisfied: msgpack>=1.0.5 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from librosa>=0.9.0->semantica) (1.2.2)
# Requirement already satisfied: cloudpickle>=3.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from joblib>=1.2->librosa>=0.9.0->semantica) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from matplotlib>=3.9.4->semantica) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from matplotlib>=3.9.4->semantica) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from matplotlib>=3.9.4->semantica) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from matplotlib>=3.9.4->semantica) (1.5.1)
# Requirement already satisfied: pyparsing>=3 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from matplotlib>=3.9.4->semantica) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from matplotlib>=3.9.4->semantica) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.50,>=0.49.0dev0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from numba>=0.61.0->librosa>=0.9.0->semantica) (0.49.0)
# Requirement already satisfied: flatbuffers in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from onnxruntime>=1.20.1->semantica) (25.12.19)
# Requirement already satisfied: et-xmlfile in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from openpyxl>=3.1.5->semantica) (2.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from pexpect>4.6->ipython>=6.1.0->ipywidgets>=8.0.0->semantica) (0.7.0)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from plotly>=6.8.0->semantica) (2.26.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from pooch>=1.7->librosa>=0.9.0->semantica) (4.11.8)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from pydantic>=2.13.4->semantica) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from pydantic>=2.13.4->semantica) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from pydantic>=2.13.4->semantica) (0.4.4)
# Requirement already satisfied: six>=1.5 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.9.4->semantica) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from rich>=12.5.0->semantica) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.5.0->semantica) (0.1.2)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from scikit-learn>=1.7.2->semantica) (3.6.0)
# Requirement already satisfied: regex>=2025.10.22 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from transformers>=4.20.0->semantica) (2026.9.10)
# Requirement already satisfied: typer in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from transformers>=4.20.0->semantica) (0.27.2)
# Requirement already satisfied: safetensors>=0.8.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from transformers>=4.20.0->semantica) (0.8.0)
# Requirement already satisfied: wrapt in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from smart_open>=1.8.1->gensim>=4.4.0->semantica) (2.4.1)
# Requirement already satisfied: cffi>=1.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from soundfile>=0.12.1->librosa>=0.9.0->semantica) (2.1.1)
# Requirement already satisfied: pycparser in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.9.0->semantica) (3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from spacy>=3.4.0->semantica) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from spacy>=3.4.0->semantica) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from spacy>=3.4.0->semantica) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from spacy>=3.4.0->semantica) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from spacy>=3.4.0->semantica) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from spacy>=3.4.0->semantica) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from spacy>=3.4.0->semantica) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from spacy>=3.4.0->semantica) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from spacy>=3.4.0->semantica) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from spacy>=3.4.0->semantica) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from spacy>=3.4.0->semantica) (1.3.3)
# Requirement already satisfied: jinja2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from spacy>=3.4.0->semantica) (3.1.6)
# Requirement already satisfied: setuptools in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from spacy>=3.4.0->semantica) (83.0.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.12->spacy>=3.4.0->semantica) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from typer->transformers>=4.20.0->semantica) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from typer->transformers>=4.20.0->semantica) (0.0.5)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy>=3.4.0->semantica) (0.25.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=8.0.0->semantica) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=8.0.0->semantica) (3.0.2)
# Requirement already satisfied: pure-eval in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=8.0.0->semantica) (0.2.4)
# Requirement already satisfied: sympy>=1.13.3 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from torch>=1.13.1->semantica) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.13.1->semantica) (1.3.0)
# Requirement already satisfied: pynndescent>=0.5 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from umap-learn>=0.5.12->semantica) (0.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/thomasliu/miniconda3/envs/semantica/lib/python3.12/site-packages (from jinja2->spacy>=3.4.0->semantica) (3.0.3)

# %% [markdown]
# ## Step 1: Initialize Graph Store
#
# Initialize a `GraphStore` instance with your preferred backend. For this tutorial, we'll use **Neo4j** (requires a running server).

# %%
from semantica.graph_store import GraphStore

# Neo4j AuraDB Connection Details
# Replace these values with your actual AuraDB credentials
store = GraphStore(
    backend="neo4j",
    uri="Your URI",  # Your AuraDB Instance URI
    user="neo4j",
    password="Your Password"  # Please enter your password here
)

# Connect to the database
store.connect()
print("Connected to graph database successfully!")

# %% [markdown]
# ## Step 2: Node Operations
#
# ### Creating Nodes
#
# Nodes represent entities in your graph. Each node can have:
# - **Labels**: Categories/types (e.g., `Person`, `Company`, `Location`)
# - **Properties**: Key-value pairs (e.g., `{"name": "Alice", "age": 30}`)

# %%
# Create individual nodes with labels and properties
apple = store.create_node(
    labels=["Company"],
    properties={"name": "Apple Inc.", "founded": 1976, "industry": "Technology"}
)
print(f"Created company node: {apple.get('properties', {}).get('name')} (ID: {apple.get('id')})")

tim_cook = store.create_node(
    labels=["Person"],
    properties={"name": "Tim Cook", "title": "CEO", "age": 63}
)
print(f"Created person node: {tim_cook.get('properties', {}).get('name')} (ID: {tim_cook.get('id')})")

cupertino = store.create_node(
    labels=["Location"],
    properties={"name": "Cupertino", "state": "California", "country": "USA"}
)
print(f"Created location node: {cupertino.get('properties', {}).get('name')} (ID: {cupertino.get('id')})")

# %%
# Create multiple nodes in batch (more efficient for large datasets)
other_companies = store.create_nodes([
    {"labels": ["Company"], "properties": {"name": "Microsoft", "founded": 1975}},
    {"labels": ["Company"], "properties": {"name": "Google", "founded": 1998}},
    {"labels": ["Company"], "properties": {"name": "Amazon", "founded": 1994}},
])
print(f"Created {len(other_companies)} company nodes in batch")

# %% [markdown]
# ## Step 3: Relationship Operations
#
# ### Creating Relationships
#
# Relationships connect nodes and represent connections between entities. Each relationship has:
# - **Type**: The relationship type (e.g., `CEO_OF`, `LOCATED_IN`, `KNOWS`)
# - **Properties**: Key-value pairs (e.g., `{"since": 2011}`)
# - **Direction**: From `start_node_id` to `end_node_id`

# %%
# Create relationships between nodes
ceo_rel = store.create_relationship(
    start_node_id=tim_cook["id"],
    end_node_id=apple["id"],
    rel_type="CEO_OF",
    properties={"since": 2011}
)
print(f"Created relationship: {ceo_rel.get('type')} (ID: {ceo_rel.get('id')})")

location_rel = store.create_relationship(
    start_node_id=apple["id"],
    end_node_id=cupertino["id"],
    rel_type="HEADQUARTERED_IN",
    properties={"since": 1977}
)
print(f"Created relationship: {location_rel.get('type')} (ID: {location_rel.get('id')})")

# %% [markdown]
# ## Step 4: Querying Nodes and Relationships
#
# ### Retrieving Nodes
#
# You can query nodes by labels, properties, or node IDs.

# %%
# Get nodes by label
companies = store.get_nodes(labels=["Company"], limit=10)
print(f"Found {len(companies)} companies:")
for company in companies:
    name = company.get('properties', {}).get('name', 'Unknown')
    founded = company.get('properties', {}).get('founded', 'N/A')
    print(f"  - {name} (founded: {founded})")

# Get a specific node by ID
if apple.get('id'):
    node = store.get_node(node_id=apple["id"])
    print(f"\nRetrieved node by ID: {node.get('properties', {}).get('name')}")

# %%
# Get relationships for a node
relationships = store.get_relationships(node_id=apple["id"], direction="both")
print(f"Found {len(relationships)} relationships for Apple:")
for rel in relationships:
    rel_type = rel.get('type', 'Unknown')
    props = rel.get('properties', {})
    print(f"  - {rel_type}: {props}")

# Get relationships by type and direction
if tim_cook.get('id'):
    outgoing = store.get_relationships(
        node_id=tim_cook["id"],
        rel_type="CEO_OF",
        direction="out"
    )
    print(f"\nOutgoing CEO_OF relationships: {len(outgoing)}")

# %% [markdown]
# ## Step 5: Cypher Query Execution
#
# ### Executing Cypher Queries
#
# Cypher is a powerful graph query language that allows you to express complex graph patterns and operations. The Graph Store module supports **OpenCypher** syntax across all backends.

# %%
# Execute a Cypher query to find CEO relationships
results = store.execute_query("""
    MATCH (p:Person)-[r:CEO_OF]->(c:Company)
    RETURN p.name as person, c.name as company, r.since as since
""")

print("CEO Relationships:")
for record in results.get("records", []):
    person = record.get('person', 'Unknown')
    company = record.get('company', 'Unknown')
    since = record.get('since', 'N/A')
    print(f"  - {person} is CEO of {company} since {since}")

# %%
# Parameterized query (safer and more efficient)
results = store.execute_query(
    "MATCH (c:Company) WHERE c.founded > $year RETURN c.name, c.founded ORDER BY c.founded",
    parameters={"year": 1990}
)

print("Companies founded after 1990:")
for record in results.get("records", []):
    name = record.get('c.name', 'Unknown')
    founded = record.get('c.founded', 'N/A')
    print(f"  - {name} (founded: {founded})")

# %% [markdown]
# ## Step 6: Graph Analytics
#
# ### Built-in Analytics Algorithms
#
# The Graph Store module provides several graph analytics algorithms for analyzing your graph structure.

# %%
# Get neighbors of a node (traverse the graph)
if apple.get('id'):
    neighbors = store.get_neighbors(
        node_id=apple["id"],
        direction="both",
        depth=2
    )
    
    print(f"Found {len(neighbors)} neighbors (up to depth 2) for Apple:")
    for neighbor in neighbors:
        name = neighbor.get('properties', {}).get('name', 'Unknown')
        labels = neighbor.get('labels', [])
        print(f"  - {name} ({', '.join(labels)})")

# %%
# Find shortest path between two nodes
if tim_cook.get('id') and cupertino.get('id'):
    path = store.shortest_path(
        start_node_id=tim_cook["id"],
        end_node_id=cupertino["id"],
        max_depth=5
    )
    
    if path:
        print(f"Shortest path found:")
        print(f"  - Path length: {path.get('length')}")
        print(f"  - Nodes in path: {len(path.get('nodes', []))}")
        print(f"  - Relationships: {len(path.get('relationships', []))}")
    else:
        print("No path found between the nodes")

# %% [markdown]
# ## Step 7: Update and Delete Operations
#
# ### Updating Nodes
#
# You can update node properties using the `update_node` method.

# %%
# Update node properties (merge mode - adds/updates properties)
if tim_cook.get('id'):
    updated = store.update_node(
        node_id=tim_cook["id"],
        properties={"age": 64, "title": "CEO & President"},
        merge=True  # Merge with existing properties
    )
    print(f"Updated node: {updated.get('properties', {}).get('name')}")
    print(f"  New age: {updated.get('properties', {}).get('age')}")
    print(f"  New title: {updated.get('properties', {}).get('title')}")

# Example: Replace all properties (merge=False)
# updated = store.update_node(
#     node_id=node_id,
#     properties={"name": "New Name"},
#     merge=False  # Replace all properties
# )

# %% [markdown]
# ## Step 8: Delete Operations
#
# ### Deleting Nodes and Relationships
#
# You can delete nodes and relationships when needed.

# %%
# Delete a relationship
if location_rel.get('id'):
    deleted = store.delete_relationship(rel_id=location_rel["id"])
    if deleted:
        print(f"Deleted relationship (ID: {location_rel['id']})")

# Delete a node (with detach=True to also delete its relationships)
# WARNING: This will delete the node and all its relationships
# Uncomment to test:
# if cupertino.get('id'):
#     deleted = store.delete_node(node_id=cupertino["id"], detach=True)
#     if deleted:
#         print(f"Deleted node: {cupertino.get('properties', {}).get('name')}")

print("\nTip: Use detach=True to delete a node and all its relationships")
print("     Use detach=False to only delete the node (fails if relationships exist)")

# %% [markdown]
# ## Step 9: Graph Statistics
#
# Get comprehensive statistics about your graph.

# %%
# Get comprehensive graph statistics
stats = store.get_stats()

print("Graph Statistics:")
print(f"  Total nodes: {stats.get('node_count', 'N/A')}")
print(f"  Total relationships: {stats.get('relationship_count', 'N/A')}")
print(f"\nNode labels:")
for label, count in stats.get('label_counts', {}).items():
    print(f"  - {label}: {count} nodes")
print(f"\nRelationship types:")
for rel_type, count in stats.get('relationship_type_counts', {}).items():
    print(f"  - {rel_type}: {count} relationships")

# %% [markdown]
# ## Step 10: Convenience Functions
#
# The Graph Store module provides convenience functions for simpler, function-based operations.

# %%
# Using convenience functions (alternative to class methods)
from semantica.graph_store import (
    create_node,
    create_relationship,
    get_nodes,
    execute_query,
    shortest_path
)

# These functions work with a default store instance
# For this example, we'll continue using the store instance we created

# Example: Using convenience functions
# node = create_node(
#     labels=["Person"],
#     properties={"name": "Alice", "age": 30}
# )

print("Convenience functions available:")
print("  - create_node, create_nodes")
print("  - create_relationship, create_relationships")
print("  - get_nodes, get_relationships")
print("  - update_node, delete_node")
print("  - execute_query, shortest_path, get_neighbors")
print("  - run_analytics")

# %% [markdown]
# ## Step 11: Index Management
#
# Create indexes to improve query performance, especially for large graphs.

# %%
# Create an index on a node property for faster lookups
# This is especially useful for frequently queried properties

index_created = store.create_index(
    label="Company",
    property_name="name",
    index_type="btree"  # Default index type
)

if index_created:
    print("Created index on Company.name for faster queries")
else:
    print("Index may already exist or not be supported by this backend")

# Note: Index creation support varies by backend
# Neo4j: Full support for various index types
# FalkorDB: Limited index support

# %% [markdown]
# ## Step 12: Clean Up
#
# Always close the connection when you're done to free up resources.

# %%
# Close the connection
store.close()
print("Connection closed successfully")

# %% [markdown]
# ## Summary
#
# This notebook covered the Graph Store module, a unified interface for property graph databases supporting Neo4j and FalkorDB.
#
# ### What You Learned
#
# - **CRUD Operations**: Create, read, update, and delete nodes and relationships
# - **Cypher Queries**: Execute complex graph queries with OpenCypher syntax
# - **Graph Analytics**: Shortest path, neighbor traversal, and centrality algorithms
# - **Batch Operations**: Efficient bulk data loading for large datasets
# - **Index Management**: Performance optimization through indexing
#
# ### Key Takeaways
#
# - **Backend Selection**: Use Neo4j for production, FalkorDB for high-performance applications
# - **Best Practices**: Use batch operations, parameterized queries, and proper connection management
# - **Next Steps**: Explore advanced analytics, graph quality, and visualization modules
